# %%
from scanner_agent import scan_folder

# %%
file_list = scan_folder('/Users/christopherguarino/downloads')
# Out:
# [{'file_name': 'ERD_Milestone1.drawio.pdf',
#   'file_path': '/Users/christopherguarino/downloads/ERD_Milestone1.drawio.pdf',
#   'file_size': 94064,
#   'file_extension': '.pdf'},
#  {'file_name': 'AnguishedPastAidi-size_restricted.gif',
#   'file_path': '/Users/christopherguarino/downloads/AnguishedPastAidi-size_restricted.gif',
#   'file_size': 2822260,
#   'file_extension': '.gif'},
#  {'file_name': 'IMG_930A23F90CAA-1.jpeg',
#   'file_path': '/Users/christopherguarino/downloads/IMG_930A23F90CAA-1.jpeg',
#   'file_size': 3591553,
#   'file_extension': '.jpeg'},
#  {'file_name': 'Guarino_ERD_Milestone1.pdf',
#   'file_path': '/Users/christopherguarino/downloads/Guarino_ERD_Milestone1.pdf',
#   'file_size': 80968,
#   'file_extension': '.pdf'},
#  {'file_name': 'addresses.csv',
#   'file_path': '/Users/christopherguarino/downloads/addresses.csv',
#   'file_size': 328,
#   'file_extension': '.csv'},
#  {'file_name': 'CS602852HW1_Guarino (1).doc',
# ...

# %%
file_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 file_list
#
# NameError: name 'file_list' is not defined
